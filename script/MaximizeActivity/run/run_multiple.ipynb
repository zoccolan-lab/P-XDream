# %%
import os
from os import path

from script.MaximizeActivity.run.run_multiple import main
from zdream.utils.io_ import read_json

# %%
# NOTE: Script directory path refers to the current script file
SCRIPT_DIR      = path.abspath(path.join(os.getcwd(), '..', '..'))
SCRIPT_SETTINGS = path.join(SCRIPT_DIR, 'local_settings.json')

# %%
settings = read_json(path=SCRIPT_SETTINGS)

gen_weights  = settings['gen_weights']
out_dir      = settings['out_dir']
mini_inet    = settings['mini_inet']
config_path  = settings['maximize_activity_config']

# %%
args = {
    'config'       : config_path,
    'weights'      : gen_weights,
    'mini_inet'    : mini_inet,
    'out_dir'      : out_dir,
    'num_gens'     : '3#4#5',
    'name'         : 'quinta',
    'display_plots': 'True'
}

# %%
main(args=args)
# Out:
# 2024-03-05 12:00:10.765 | INFO     | zdream.logger:info:226 - Creating experiment directory /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-0
# 2024-03-05 12:00:10.767 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:00:10.770 | INFO     | zdream.logger:info:226 - Experiment[quinta]
# 2024-03-05 12:00:10.772 | INFO     | zdream.logger:info:226 - Parameters:
# 2024-03-05 12:00:10.774 | INFO     | zdream.logger:info:226 - config:          /home/sebaq/Documents/GitHub/ZXDREAM/config/maximize_activity.json
# 2024-03-05 12:00:10.776 | INFO     | zdream.logger:info:226 - weights:         /home/sebaq/Documents/GitHub/ZXDREAM/data/inverse-alexnet-weights
# 2024-03-05 12:00:10.778 | INFO     | zdream.logger:info:226 - mini_inet:       /home/sebaq/Documents/GitHub/ZXDREAM/data/mini-inet
# 2024-03-05 12:00:10.779 | INFO     | zdream.logger:info:226 - batch_size:      2
# 2024-03-05 12:00:10.781 | INFO     | zdream.logger:info:226 - variant:         fc8
# 2024-03-05 12:00:10.782 | INFO     | zdream.logger:info:226 - template:        TFFFF
# 2024-03-05 12:00:10.784 | INFO     | zdream.logger:info:226 - shuffle:         False
# 2024-03-05 12:00:10.786 | INFO     | zdream.logger:info:226 - net_name:        alexnet
# 2024-03-05 12:00:10.788 | INFO     | zdream.logger:info:226 - rec_layers:      21:[]
# 2024-03-05 12:00:10.790 | INFO     | zdream.logger:info:226 - targets:         21:[0_19]
# 2024-03-05 12:00:10.792 | INFO     | zdream.logger:info:226 - aggregation:     mean
# 2024-03-05 12:00:10.793 | INFO     | zdream.logger:info:226 - scr_rseed:       31415
# 2024-03-05 12:00:10.794 | INFO     | zdream.logger:info:226 - pop_sz:          20
# 2024-03-05 12:00:10.796 | INFO     | zdream.logger:info:226 - optim_rseed:     123
# 2024-03-05 12:00:10.797 | INFO     | zdream.logger:info:226 - mutation_rate:   0.3
# 2024-03-05 12:00:10.798 | INFO     | zdream.logger:info:226 - mutation_size:   0.3
# 2024-03-05 12:00:10.800 | INFO     | zdream.logger:info:226 - num_parents:     3
# 2024-03-05 12:00:10.801 | INFO     | zdream.logger:info:226 - temperature:     1.0
# 2024-03-05 12:00:10.803 | INFO     | zdream.logger:info:226 - random_state:    normal
# 2024-03-05 12:00:10.805 | INFO     | zdream.logger:info:226 - out_dir:         /home/sebaq/Documents/GitHub/ZXDREAM/out
# 2024-03-05 12:00:10.806 | INFO     | zdream.logger:info:226 - name:            quinta
# 2024-03-05 12:00:10.808 | INFO     | zdream.logger:info:226 - version:         0
# 2024-03-05 12:00:10.810 | INFO     | zdream.logger:info:226 - title:           MaximizeActivity
# 2024-03-05 12:00:10.813 | INFO     | zdream.logger:info:226 - num_gens:        3
# 2024-03-05 12:00:10.814 | INFO     | zdream.logger:info:226 - display_plots:   True
# 2024-03-05 12:00:10.816 | INFO     | zdream.logger:info:226 - Saving param configuration to: /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-0/params.json
# 2024-03-05 12:00:10.818 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:00:10.819 | INFO     | zdream.logger:info:226 - Components:
# 2024-03-05 12:00:10.821 | INFO     | zdream.logger:info:226 - Generator: InverseAlexNetGenerator[variant: fc8; in-dim: (1000,); out-dim: (3, 256, 256)]
# 2024-03-05 12:00:10.825 | INFO     | zdream.logger:info:226 - Subject:   NetworkSubject[name: alexnet, in-shape: (1, 3, 224, 224), n-layers: 22, n-probes: 1]
# 2024-03-05 12:00:10.827 | INFO     | zdream.logger:info:226 - Scorer:    MaximizeActivityScorer[target neurons: (21_linear_03: 19 units)]
# 2024-03-05 12:00:10.829 | INFO     | zdream.logger:info:226 - Optimizer: GeneticOptimizer[n_states: 20; n_parents: 3; temperature: 1.0; mutation_size: 0.3; mutation_rate: 0.3]
# 2024-03-05 12:00:10.830 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:00:10.944 | INFO     | zdream.logger:info:226 - Running...
# 2024-03-05 12:00:14.845 | INFO     | zdream.logger:info:226 - Experiment[quinta]: [1/3] (33.33%) | best score: 2.2 | avg score: 0.8 | best nat: 7.4
# 2024-03-05 12:00:19.288 | INFO     | zdream.logger:info:226 - Experiment[quinta]: [2/3] (66.67%) | best score: 3.0 | avg score: 1.2 | best nat: 10.4
# 2024-03-05 12:00:23.186 | INFO     | zdream.logger:info:226 - Experiment[quinta]: [3/3] (100.00%) | best score: 3.1 | avg score: 1.6 | best nat: 14.3
# 2024-03-05 12:00:23.277 | INFO     | zdream.logger:info:226 - Experiment finished successfully. Elapsed time: 12 seconds s.
# 2024-03-05 12:00:23.278 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:00:23.314 | INFO     | zdream.logger:info:226 - Dumping experiment to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-0/state
# 2024-03-05 12:00:23.316 | INFO     | zdream.logger:info:226 - > Saving mask history to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-0/state/mask.npy
# 2024-03-05 12:00:23.318 | INFO     | zdream.logger:info:226 - > Saving labels history to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-0/state/labels.npy
# 2024-03-05 12:00:23.323 | INFO     | zdream.logger:info:226 - > Saving states history to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-0/state/states.npz
# 2024-03-05 12:00:23.327 | INFO     | zdream.logger:info:226 - > Saving codes history to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-0/state/codes.npy
# 2024-03-05 12:00:23.330 | INFO     | zdream.logger:info:226 - > Saving scores history to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-0/state/scores.npy
# 2024-03-05 12:00:23.335 | INFO     | zdream.logger:info:226 - > Saving scores of natural images history to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-0/state/scores_nat.npy
# 2024-03-05 12:00:23.341 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:00:23.345 | INFO     | zdream.logger:info:226 - Saving images to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-0/images
# 2024-03-05 12:00:24.275 | INFO     | zdream.logger:info:226 - Saving plots to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-0/images
# 2024-03-05 12:00:32.901 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:00:36.742 | INFO     | zdream.logger:info:226 - Creating experiment directory /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-1
# 2024-03-05 12:00:36.744 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:00:36.746 | INFO     | zdream.logger:info:226 - Experiment[quinta]
# 2024-03-05 12:00:36.750 | INFO     | zdream.logger:info:226 - Parameters:
# 2024-03-05 12:00:36.752 | INFO     | zdream.logger:info:226 - config:          /home/sebaq/Documents/GitHub/ZXDREAM/config/maximize_activity.json
# 2024-03-05 12:00:36.754 | INFO     | zdream.logger:info:226 - weights:         /home/sebaq/Documents/GitHub/ZXDREAM/data/inverse-alexnet-weights
# 2024-03-05 12:00:36.756 | INFO     | zdream.logger:info:226 - mini_inet:       /home/sebaq/Documents/GitHub/ZXDREAM/data/mini-inet
# 2024-03-05 12:00:36.758 | INFO     | zdream.logger:info:226 - batch_size:      2
# 2024-03-05 12:00:36.760 | INFO     | zdream.logger:info:226 - variant:         fc8
# 2024-03-05 12:00:36.762 | INFO     | zdream.logger:info:226 - template:        TFFFF
# 2024-03-05 12:00:36.765 | INFO     | zdream.logger:info:226 - shuffle:         False
# 2024-03-05 12:00:36.767 | INFO     | zdream.logger:info:226 - net_name:        alexnet
# 2024-03-05 12:00:36.769 | INFO     | zdream.logger:info:226 - rec_layers:      21:[]
# 2024-03-05 12:00:36.771 | INFO     | zdream.logger:info:226 - targets:         21:[0_19]
# 2024-03-05 12:00:36.774 | INFO     | zdream.logger:info:226 - aggregation:     mean
# 2024-03-05 12:00:36.776 | INFO     | zdream.logger:info:226 - scr_rseed:       31415
# 2024-03-05 12:00:36.778 | INFO     | zdream.logger:info:226 - pop_sz:          20
# 2024-03-05 12:00:36.780 | INFO     | zdream.logger:info:226 - optim_rseed:     123
# 2024-03-05 12:00:36.782 | INFO     | zdream.logger:info:226 - mutation_rate:   0.3
# 2024-03-05 12:00:36.783 | INFO     | zdream.logger:info:226 - mutation_size:   0.3
# 2024-03-05 12:00:36.785 | INFO     | zdream.logger:info:226 - num_parents:     3
# 2024-03-05 12:00:36.787 | INFO     | zdream.logger:info:226 - temperature:     1.0
# 2024-03-05 12:00:36.789 | INFO     | zdream.logger:info:226 - random_state:    normal
# 2024-03-05 12:00:36.791 | INFO     | zdream.logger:info:226 - out_dir:         /home/sebaq/Documents/GitHub/ZXDREAM/out
# 2024-03-05 12:00:36.793 | INFO     | zdream.logger:info:226 - name:            quinta
# 2024-03-05 12:00:36.795 | INFO     | zdream.logger:info:226 - version:         0
# 2024-03-05 12:00:36.797 | INFO     | zdream.logger:info:226 - title:           MaximizeActivity
# 2024-03-05 12:00:36.799 | INFO     | zdream.logger:info:226 - num_gens:        4
# 2024-03-05 12:00:36.800 | INFO     | zdream.logger:info:226 - display_plots:   True
# 2024-03-05 12:00:36.803 | INFO     | zdream.logger:info:226 - Saving param configuration to: /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-1/params.json
# 2024-03-05 12:00:36.805 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:00:36.808 | INFO     | zdream.logger:info:226 - Components:
# 2024-03-05 12:00:36.810 | INFO     | zdream.logger:info:226 - Generator: InverseAlexNetGenerator[variant: fc8; in-dim: (1000,); out-dim: (3, 256, 256)]
# 2024-03-05 12:00:36.813 | INFO     | zdream.logger:info:226 - Subject:   NetworkSubject[name: alexnet, in-shape: (1, 3, 224, 224), n-layers: 22, n-probes: 1]
# 2024-03-05 12:00:36.815 | INFO     | zdream.logger:info:226 - Scorer:    MaximizeActivityScorer[target neurons: (21_linear_03: 19 units)]
# 2024-03-05 12:00:36.818 | INFO     | zdream.logger:info:226 - Optimizer: GeneticOptimizer[n_states: 20; n_parents: 3; temperature: 1.0; mutation_size: 0.3; mutation_rate: 0.3]
# 2024-03-05 12:00:36.820 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:00:36.929 | INFO     | zdream.logger:info:226 - Running...
# 2024-03-05 12:00:41.183 | INFO     | zdream.logger:info:226 - Experiment[quinta]: [1/4] (25.00%) | best score: 2.2 | avg score: 0.8 | best nat: 11.0
# 2024-03-05 12:00:45.197 | INFO     | zdream.logger:info:226 - Experiment[quinta]: [2/4] (50.00%) | best score: 3.0 | avg score: 1.2 | best nat: 13.1
# 2024-03-05 12:00:48.861 | INFO     | zdream.logger:info:226 - Experiment[quinta]: [3/4] (75.00%) | best score: 3.1 | avg score: 1.6 | best nat: 13.1
# 2024-03-05 12:00:52.389 | INFO     | zdream.logger:info:226 - Experiment[quinta]: [4/4] (100.00%) | best score: 4.3 | avg score: 2.0 | best nat: 13.1
# 2024-03-05 12:00:52.475 | INFO     | zdream.logger:info:226 - Experiment finished successfully. Elapsed time: 15 seconds s.
# 2024-03-05 12:00:52.477 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:00:52.518 | INFO     | zdream.logger:info:226 - Dumping experiment to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-1/state
# 2024-03-05 12:00:52.520 | INFO     | zdream.logger:info:226 - > Saving mask history to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-1/state/mask.npy
# 2024-03-05 12:00:52.522 | INFO     | zdream.logger:info:226 - > Saving labels history to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-1/state/labels.npy
# 2024-03-05 12:00:52.525 | INFO     | zdream.logger:info:226 - > Saving states history to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-1/state/states.npz
# 2024-03-05 12:00:52.531 | INFO     | zdream.logger:info:226 - > Saving codes history to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-1/state/codes.npy
# 2024-03-05 12:00:52.536 | INFO     | zdream.logger:info:226 - > Saving scores history to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-1/state/scores.npy
# 2024-03-05 12:00:52.550 | INFO     | zdream.logger:info:226 - > Saving scores of natural images history to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-1/state/scores_nat.npy
# 2024-03-05 12:00:52.554 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:00:52.558 | INFO     | zdream.logger:info:226 - Saving images to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-1/images
# 2024-03-05 12:00:53.610 | INFO     | zdream.logger:info:226 - Saving plots to /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-1/images
# 2024-03-05 12:01:00.279 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:01:03.257 | INFO     | zdream.logger:info:226 - Creating experiment directory /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-2
# 2024-03-05 12:01:03.263 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:01:03.265 | INFO     | zdream.logger:info:226 - Experiment[quinta]
# 2024-03-05 12:01:03.268 | INFO     | zdream.logger:info:226 - Parameters:
# 2024-03-05 12:01:03.270 | INFO     | zdream.logger:info:226 - config:          /home/sebaq/Documents/GitHub/ZXDREAM/config/maximize_activity.json
# 2024-03-05 12:01:03.272 | INFO     | zdream.logger:info:226 - weights:         /home/sebaq/Documents/GitHub/ZXDREAM/data/inverse-alexnet-weights
# 2024-03-05 12:01:03.278 | INFO     | zdream.logger:info:226 - mini_inet:       /home/sebaq/Documents/GitHub/ZXDREAM/data/mini-inet
# 2024-03-05 12:01:03.281 | INFO     | zdream.logger:info:226 - batch_size:      2
# 2024-03-05 12:01:03.284 | INFO     | zdream.logger:info:226 - variant:         fc8
# 2024-03-05 12:01:03.286 | INFO     | zdream.logger:info:226 - template:        TFFFF
# 2024-03-05 12:01:03.289 | INFO     | zdream.logger:info:226 - shuffle:         False
# 2024-03-05 12:01:03.292 | INFO     | zdream.logger:info:226 - net_name:        alexnet
# 2024-03-05 12:01:03.295 | INFO     | zdream.logger:info:226 - rec_layers:      21:[]
# 2024-03-05 12:01:03.299 | INFO     | zdream.logger:info:226 - targets:         21:[0_19]
# 2024-03-05 12:01:03.303 | INFO     | zdream.logger:info:226 - aggregation:     mean
# 2024-03-05 12:01:03.305 | INFO     | zdream.logger:info:226 - scr_rseed:       31415
# 2024-03-05 12:01:03.308 | INFO     | zdream.logger:info:226 - pop_sz:          20
# 2024-03-05 12:01:03.311 | INFO     | zdream.logger:info:226 - optim_rseed:     123
# 2024-03-05 12:01:03.314 | INFO     | zdream.logger:info:226 - mutation_rate:   0.3
# 2024-03-05 12:01:03.317 | INFO     | zdream.logger:info:226 - mutation_size:   0.3
# 2024-03-05 12:01:03.321 | INFO     | zdream.logger:info:226 - num_parents:     3
# 2024-03-05 12:01:03.326 | INFO     | zdream.logger:info:226 - temperature:     1.0
# 2024-03-05 12:01:03.328 | INFO     | zdream.logger:info:226 - random_state:    normal
# 2024-03-05 12:01:03.330 | INFO     | zdream.logger:info:226 - out_dir:         /home/sebaq/Documents/GitHub/ZXDREAM/out
# 2024-03-05 12:01:03.333 | INFO     | zdream.logger:info:226 - name:            quinta
# 2024-03-05 12:01:03.336 | INFO     | zdream.logger:info:226 - version:         0
# 2024-03-05 12:01:03.339 | INFO     | zdream.logger:info:226 - title:           MaximizeActivity
# 2024-03-05 12:01:03.342 | INFO     | zdream.logger:info:226 - num_gens:        5
# 2024-03-05 12:01:03.346 | INFO     | zdream.logger:info:226 - display_plots:   True
# 2024-03-05 12:01:03.350 | INFO     | zdream.logger:info:226 - Saving param configuration to: /home/sebaq/Documents/GitHub/ZXDREAM/out/MaximizeActivity/quinta/quinta-2/params.json
# 2024-03-05 12:01:03.353 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:01:03.360 | INFO     | zdream.logger:info:226 - Components:
# 2024-03-05 12:01:03.363 | INFO     | zdream.logger:info:226 - Generator: InverseAlexNetGenerator[variant: fc8; in-dim: (1000,); out-dim: (3, 256, 256)]
# 2024-03-05 12:01:03.368 | INFO     | zdream.logger:info:226 - Subject:   NetworkSubject[name: alexnet, in-shape: (1, 3, 224, 224), n-layers: 22, n-probes: 1]
# 2024-03-05 12:01:03.375 | INFO     | zdream.logger:info:226 - Scorer:    MaximizeActivityScorer[target neurons: (21_linear_03: 19 units)]
# 2024-03-05 12:01:03.380 | INFO     | zdream.logger:info:226 - Optimizer: GeneticOptimizer[n_states: 20; n_parents: 3; temperature: 1.0; mutation_size: 0.3; mutation_rate: 0.3]
# 2024-03-05 12:01:03.382 | INFO     | zdream.logger:info:226 -
# 2024-03-05 12:01:03.560 | INFO     | zdream.logger:info:226 - Running...
# 2024-03-05 12:01:07.359 | INFO     | zdream.logger:info:226 - Experiment[quinta]: [1/5] (20.00%) | best score: 2.2 | avg score: 0.8 | best nat: 14.0
# 2024-03-05 12:01:11.716 | INFO     | zdream.logger:info:226 - Experiment[quinta]: [2/5] (40.00%) | best score: 3.0 | avg score: 1.2 | best nat: 14.0
# 2024-03-05 12:01:15.684 | INFO     | zdream.logger:info:226 - Experiment[quinta]: [3/5] (60.00%) | best score: 3.1 | avg score: 1.6 | best nat: 14.0
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 main(args=args)
#
# File ~/Documents/GitHub/ZXDREAM/script/MaximizeActivity/run/run_multiple.py:71, in main(args)
#      63 args_conf = {k : v * n_args if len(v) == 1 else v for k, v in args_conf.items()}
#      65 mrun_experiment = MultiExperiment(
#      66     experiment=_MaximizeActivityExperiment,
#      67     base_config=json_conf,
#      68     search_config=args_conf
#      69 )
# ---> 71 mrun_experiment.run()
#
# File ~/Documents/GitHub/ZXDREAM/zdream/experiment.py:586, in MultiExperiment.run(self)
#     583 exp_config = overwrite_dict(self._base_config, conf)
#     584 exp = self._Exp.from_config(exp_config)
# --> 586 exp.run()
#
# File ~/Documents/GitHub/ZXDREAM/zdream/experiment.py:534, in Experiment.run(self)
#     530 self._init()
#     532 start_time = time.time()
# --> 534 self._run()
#     536 end_time = time.time()
#     538 self._elapsed_time = end_time - start_time
#
# File ~/Documents/GitHub/ZXDREAM/zdream/experiment.py:517, in Experiment._run(self)
#     514 stm_score = self._sbj_state_to_stm_score(sbj_state)
#     515 codes     = self._stm_score_to_codes(stm_score)
# --> 517 self._progress(i=i)
#
# File ~/Documents/GitHub/ZXDREAM/script/MaximizeActivity/maximize_activity.py:216, in _MaximizeActivityExperiment._progress(self, i)
#     212 best_synthetic_img = to_pil_image(best_synthetic[0])
#     214 best_natural = self._best_img['nat']
# --> 216 self._logger.update_screen(
#     217     screen_name=self._screen_syn,
#     218     image=best_synthetic_img
#     219 )
#     221 self._logger.update_screen(
#     222     screen_name=self._screen_nat,
#     223     image=to_pil_image(best_natural)
#     224 )
#     226 if not self._gif or self._gif[-1] != best_synthetic_img:
#
# File ~/Documents/GitHub/ZXDREAM/zdream/logger.py:159, in Logger.update_screen(self, screen_name, image)
#     149 '''
#     150 Update a display screen with a new image. It raises a key error if that screen name doesn't exist.
#     151
#    (...)
#     155 :type image: Image.Image
#     156 '''
#     158 try:
# --> 159 	self._screens[screen_name].update(image=image)
#     161 except KeyError:
#     162 	raise KeyError(f'Screen {screen_name} not present in screens {self._screens.keys()}.')
#
# File ~/Documents/GitHub/ZXDREAM/zdream/utils/model.py:218, in DisplayScreen.update(self, image)
#     215 photo = ImageTk.PhotoImage(resized_image)
#     217 # Configure the label with the resized image
# --> 218 self._image_label.configure(image=photo)
#     219 self._image_label.image = photo              # type: ignore
#     221 # Update the frame
#
# File ~/miniconda3/envs/zdream/lib/python3.11/tkinter/__init__.py:1721, in Misc.configure(self, cnf, **kw)
#    1714 def configure(self, cnf=None, **kw):
#    1715     """Configure resources of a widget.
#    1716
#    1717     The values for resources are specified as keyword
#    1718     arguments. To get an overview about
#    1719     the allowed keyword arguments call the method keys.
#    1720     """
# -> 1721     return self._configure('configure', cnf, kw)
#
# File ~/miniconda3/envs/zdream/lib/python3.11/tkinter/__init__.py:1711, in Misc._configure(self, cmd, cnf, kw)
#    1709 if isinstance(cnf, str):
#    1710     return self._getconfigure1(_flatten((self._w, cmd, '-'+cnf)))
# -> 1711 self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
#
# TclError: invalid command name ".!toplevel5.!frame.!label"
